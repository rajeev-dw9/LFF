# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F

# %%
model_d = torch.load('/home/rajeev/rrd/LFF/LOGS/logs_mlp_kl/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_f_kl_d.th')
state_dict1 = model_d['state_dict']
model_b= torch.load('/home/rajeev/rrd/LFF/LOGS/logs_mlp_kl/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_f_kl_b.th')
state_dict2 = model_b['state_dict']

a0 = F.cosine_similarity(state_dict1['feature.0.weight'],state_dict2['feature.0.weight']).mean()
print(f'layer 0: {a0}')
a2 = F.cosine_similarity(state_dict1['feature.2.weight'],state_dict2['feature.2.weight']).mean()
print(f'layer 2: {a2}')
a4 = F.cosine_similarity(state_dict1['feature.4.weight'],state_dict2['feature.4.weight']).mean()
print(f'layer 4: {a4}')
a6 = F.cosine_similarity(state_dict1['classifier.weight'],state_dict2['classifier.weight']).mean()
print(f'layer classifier: {a6}')
# Out:
# layer 0: 0.09651441127061844
# layer 2: 0.01901189610362053
# layer 4: -0.002176480134949088
# layer classifier: 0.013381603173911572

# %%
model_d = torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_d_cosine__neg__0.01__t2.th')
state_dict1 = model_d['state_dict']
model_b= torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_b_cosine__neg__0.01__t2.th')
state_dict2 = model_b['state_dict']

a0 = F.cosine_similarity(state_dict1['feature.0.weight'],state_dict2['feature.0.weight']).mean()
print(f'layer 0: {a0}')
a2 = F.cosine_similarity(state_dict1['feature.2.weight'],state_dict2['feature.2.weight']).mean()
print(f'layer 2: {a2}')
a4 = F.cosine_similarity(state_dict1['feature.4.weight'],state_dict2['feature.4.weight']).mean()
print(f'layer 4: {a4}')
a6 = F.cosine_similarity(state_dict1['classifier.weight'],state_dict2['classifier.weight']).mean()
print(f'layer classifier: {a6}')
# Out:
# layer 0: 0.011727418750524521
# layer 2: 0.998369038105011
# layer 4: 0.9974470138549805
# layer classifier: 0.09822430461645126

# %%
model_d = torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_d_cosine__neg__0.01__t3.th')
state_dict1 = model_d['state_dict']
model_b= torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_b_cosine__neg__0.01__t3.th')
state_dict2 = model_b['state_dict']

a0 = F.cosine_similarity(state_dict1['feature.0.weight'],state_dict2['feature.0.weight']).mean()
print(f'layer 0: {a0}')
a2 = F.cosine_similarity(state_dict1['feature.2.weight'],state_dict2['feature.2.weight']).mean()
print(f'layer 2: {a2}')
a4 = F.cosine_similarity(state_dict1['feature.4.weight'],state_dict2['feature.4.weight']).mean()
print(f'layer 4: {a4}')
a6 = F.cosine_similarity(state_dict1['classifier.weight'],state_dict2['classifier.weight']).mean()
print(f'layer classifier: {a6}')
# Out:
# layer 0: 0.011727418750524521
# layer 2: 0.998369038105011
# layer 4: 0.9974470138549805
# layer classifier: 0.09822430461645126

# %%
model_d = torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_d_cosine__neg__0.01__t4.th')
state_dict1 = model_d['state_dict']
model_b= torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_b_cosine__neg__0.01__t4.th')
state_dict2 = model_b['state_dict']

a0 = F.cosine_similarity(state_dict1['feature.0.weight'],state_dict2['feature.0.weight']).mean()
print(f'layer 0: {a0}')
a2 = F.cosine_similarity(state_dict1['feature.2.weight'],state_dict2['feature.2.weight']).mean()
print(f'layer 2: {a2}')
a4 = F.cosine_similarity(state_dict1['feature.4.weight'],state_dict2['feature.4.weight']).mean()
print(f'layer 4: {a4}')
a6 = F.cosine_similarity(state_dict1['classifier.weight'],state_dict2['classifier.weight']).mean()
print(f'layer classifier: {a6}')
# Out:
# layer 0: -0.0014705973444506526
# layer 2: -0.95289546251297
# layer 4: -0.9584648013114929
# layer classifier: 0.04045557230710983

# %%
model_d = torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_d_cosine__neg__24.th')
state_dict1 = model_d['state_dict']
model_b= torch.load('/home/rajeev/rrd/LFF/LOGS/log_new_10June/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_b_cosine__neg__24.th')
state_dict2 = model_b['state_dict']

a0 = F.cosine_similarity(state_dict1['feature.0.weight'],state_dict2['feature.0.weight']).mean()
print(f'layer 0: {a0}')
a2 = F.cosine_similarity(state_dict1['feature.2.weight'],state_dict2['feature.2.weight']).mean()
print(f'layer 2: {a2}')
a4 = F.cosine_similarity(state_dict1['feature.4.weight'],state_dict2['feature.4.weight']).mean()
print(f'layer 4: {a4}')
a6 = F.cosine_similarity(state_dict1['classifier.weight'],state_dict2['classifier.weight']).mean()
print(f'layer classifier: {a6}')
# Out:
# layer 0: -0.00017582654254511
# layer 2: 0.0069567798636853695
# layer 4: 0.010411105118691921
# layer classifier: 0.04912257939577103

# %% [markdown]
# | Type | Layer 0 | Layer 2 | Layer 4 | Layer Classifier | Accuracy
# |---|---|---|---|---| --- |
# | 1 | 0.0006584900547750294 | -0.9613588452339172 | 0.024809779599308968 | 0.04514903947710991 | 74.87 |
# | 2 | 0.011727418750524521 | 0.998369038105011 | 0.9974470138549805 | 0.09822430461645126 | 72.80 |
# | 3 | 0.011727418750524521 | 0.998369038105011 | 0.9974470138549805 | 0.09822430461645126 | 72.80 |
# | 4 | -0.0014705973444506526 | -0.95289546251297 | -0.9584648013114929 | 0.04045557230710983 | **77.87** |
# | 5(LFF) | -0.00017582654254511 | 0.0069567798636853695 | 0.010411105118691921 | 0.04912257939577103 | 73.17 |

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [[0.0006584900547750294, -0.9613588452339172, 0.024809779599308968, 0.04514903947710991],
        [0.011727418750524521, 0.998369038105011, 0.9974470138549805, 0.09822430461645126],
        [0.011727418750524521, 0.998369038105011, 0.9974470138549805, 0.09822430461645126],
        [-0.0014705973444506526, -0.95289546251297, -0.9584648013114929, 0.04045557230710983],
        [-0.00017582654254511, 0.0069567798636853695, 0.010411105118691921, 0.04912257939577103]]

columns = ('layer 0', 'layer 2', 'layer 4', 'layer classifier')

rows = ['t1', 't2', 't3', 't4', 't5']

values = np.arange(0, 1, 0.2)

# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 1, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Make the plot
plt.figure(figsize=(20, 5))
cell_text = []
for row in range(n_rows):
        plt.bar(index, data[row], bar_width, bottom=np.sum(data[:row], axis=0), color=colors[row])
        cell_text.append(data[row])
# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                            rowLabels=rows,
                                rowColours=colors,

                                colLabels=columns,
                                loc='bottom')

# %%
model_d = torch.load('/home/rajeev/rrd/LFF/LOGS/logs_mlp_kl_LFF_D_update/colored_mnist/result/ColoredMNIST-Skewed0.01-Severity4/model_f_kl_1_d__0___ortho.th')
state_dict1 = model_d['state_dict']
print(state_dict1.keys())
# Out:
# odict_keys(['l1.weight', 'l1.bias', 'l2.weight', 'l2.bias', 'l3.weight', 'l3.bias', 'classifier.weight', 'classifier.bias'])
